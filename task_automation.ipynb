# %%
import os
import shutil

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user

# %%
import os
import shutil

source_folder = r"C:\Users\user\source_image"
destination_folder = r"C:\Users\user\destination_images"

for file_name in os.listdir(source_folder):
    if file_name.endswith(".png"):
        source_path = os.path.join(source_folder, file_name)
        destination_path = os.path.join(destination_folder, file_name)

        shutil.move(source_path, destination_path)
        print(f"Moved: {file_name}")

print("All PNG files moved successfully!")
# Out:
# Moved: 1 - Copy - Copy.png
# Moved: 3.png
# Moved: 4 - Copy.png
# Moved: dashboard1.png
# All PNG files moved successfully!
