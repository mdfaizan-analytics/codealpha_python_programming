# %%
import random
print("welcome to hangman game")
# Out:
# welcome to hangman game

# %%
words = ["apple","python",
         "school","orange","chair"]
print(words)
# Out:
# ['apple', 'python', 'school', 'orange', 'chair']

# %%
secret_word = random.choice(words)

print(secret_word)
# Out:
# chair

# %%
guessed_letters = []
wrong_guesses = 0
max_wrong = 6

# %%
for letter in secret_word:
    if letter in guessed_letters:
        print(letter, end=" ")
    else: 
        print("_", end=" ")
# Out:
# _ _ _ _ _

# %%
guess = input("enter a letter : ").lower()

print("you entered:", guess)
# Out:
# enter a letter :  p
# you entered: p

# %%
if guess in secret_word:
    guessed_letters.append(guess)
    print("correct guess !")
else:
    wrong_guesses += 1
    print("wrong guess!")
    print("remaining chances P:",
 max_wrong - wrong_guesses)
# Out:
# wrong guess!
# remaining chances P: 5

# %%
guess = input("enter a letter :").lower()

print("you entered:", guess)
# Out:
# enter a letter : a
# you entered: a

# %%
if guess in secret_word:
    guessed_letters.append(guess)
    print("correct guess!")
else:
    wrong_guesses += 1
    print("wrong guess!")
    print("remaining chances :",
max_wrong - wrong_guesses)
# Out:
# correct guess!

# %%
for letter in secret_word:
    if letter in guessed_letters:
        print(letter , end=" ")
    else:
        print("_", end =" ")
# Out:
# _ _ a _ _

# %%
import random

words = ["chair", "python", "school", "orange", "apple"]

secret_word = random.choice(words)

guessed_letters = []
wrong_guesses = 0
max_wrong = 6

while wrong_guesses < max_wrong:

    # Display the word
    display = ""

    for letter in secret_word:
        if letter in guessed_letters:
            display += letter + " "
        else:
            display += "_ "

    print("\nWord:", display)

    # Check if player has won
    if "_" not in display:
        print("🎉 Congratulations! You guessed the word.")
        break

    # Ask for input
    guess = input("Enter a letter: ").lower()

    # Check the guess
    if guess in guessed_letters:
        print("You already guessed that letter.")

    elif guess in secret_word:
        guessed_letters.append(guess)
        print("✅ Correct!")

    else:
        wrong_guesses += 1
        print("❌ Wrong!")
        print("Remaining chances:", max_wrong - wrong_guesses)

# If player loses
if wrong_guesses == max_wrong:
    print("\nGame Over!")
    print("The word was:", secret_word)
# Out:
# Word: _ _ _ _ _
# Enter a letter:  c
# ❌ Wrong!
# Remaining chances: 5
#
# Word: _ _ _ _ _
# Enter a letter:  c
# ❌ Wrong!
# Remaining chances: 4
#
# Word: _ _ _ _ _
# Enter a letter:
# ✅ Correct!
#
# Word: _ _ _ _ _
# Enter a letter:
# You already guessed that letter.
#
# Word: _ _ _ _ _
# Enter a letter:
# You already guessed that letter.
#
# Word: _ _ _ _ _
# Enter a letter:  p
# ✅ Correct!
#
# Word: _ p p _ _
